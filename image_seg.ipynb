# %%
# 0 : noise/background 
# 1 : potato
# 2 : clutter

# %%
# 1. load data
# 2. image segmentation model
# 3.

# %%
from tensorflow import keras

# %%
import segmentation_models as sm

model = sm.Unet('resnet50', input_shape=(256, 256, 3), classes=3, activation='softmax')
model.compile('Adam', loss=sm.losses.categorical_crossentropy, metrics=[sm.metrics.iou_score])
